# %% [markdown]
# # Pattern Recognition in Daily Top Trending YouTube Videos
#
# Word2Vec Word Embedding Sub-Experiment

# %% [markdown]
# ## Setup

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
import numpy as np
import re
import seaborn as sns
from gensim.test.utils import common_texts
from gensim.models import Phrases
import nltk
from nltk.corpus import stopwords
from sklearn import preprocessing
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
from tensorflow import keras

# !pip install -q git+https://github.com/tensorflow/docs
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling

# %matplotlib inline
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will switch to TensorFlow 2.x on the 27th of March, 2020.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
#   Building wheel for tensorflow-docs (setup.py) ... done

# %% [markdown]
# **Load Data From Google Drive**

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Read-in CSV & JSON**

# %%
videos = pd.read_csv("/content/drive/My Drive/cs6140 project/data/USvideos.csv")
videos_categories = pd.read_json("/content/drive/My Drive/cs6140 project/data/US_category_id.json")

# %%
videos.head(1)
# Out:
#       video_id  ...                                        description
# 0  2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
#
# [1 rows x 16 columns]

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# This block of code links the csv to json categories

# %%
# source: https://www.kaggle.com/skalskip/youtube-data-exploration-and-plotly-visualization

categories = {category['id']: category['snippet']['title'] for category in videos_categories['items']}
videos.insert(4, 'category', videos['category_id'].astype(str).map(categories))

# %% [markdown]
# Remove NaN Errors

# %%
print(videos.shape[0])
# Out:
# 40949

# %%
videos = videos.dropna()

# %%
print(videos.shape[0])
# Out:
# 40379

# %% [markdown]
# **Creating New Attributes**

# %%
videos["likes_per_view"] = videos["likes"]/videos["views"]
videos["dislikes_per_view"] = videos["dislikes"]/videos["views"]
videos["comments_per_view"] = videos["comment_count"]/videos["views"]

videos["total_likes_dislikes"] = videos["likes"] + videos["dislikes"]
videos["total_likes_dislikes_per_view"] = videos["total_likes_dislikes"]/videos["views"]

videos["likes_percentage"] = videos["likes"]/videos["total_likes_dislikes"]
videos["dislikes_percentage"] =videos["dislikes"]/videos["total_likes_dislikes"]

# %%
# source https://www.kaggle.com/skalskip/youtube-data-exploration-and-plotly-visualization

videos['trending_date'] = pd.to_datetime(videos['trending_date'], format='%y.%d.%m').dt.date
reformatted_time = pd.to_datetime(videos['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ')
videos['publish_date'] = reformatted_time.dt.date
videos['publish_time'] = reformatted_time.dt.time
videos['publish_hour'] = reformatted_time.dt.hour

# %% [markdown]
# **Text Pre-Processing**

# %%
# get the number of characters in a given title
videos["title_characters"] = videos["title"].apply(lambda x : len(x))
# get the number of words in a given title
videos["title_words"] = videos["title"].apply(lambda x : len(x.split()))

# %%
# get the number of characters in a given description
videos["description_characters"] = videos["description"].apply(lambda x : len(str(x)))
# get the number of words in a given description
videos["description_words"] = videos["description"].apply(lambda x : len(str(x).split()))

# %% [markdown]
# **Normalize**

# %%
videos = videos.dropna()

# %%
videos.sample(1)
# Out:
#           video_id trending_date  ... description_characters description_words
# 36802  PTQMog9u2Zo    2018-05-25  ...                    439                61
#
# [1 rows x 30 columns]

# %%
min_max_scaler = preprocessing.MinMaxScaler()

col = ['views','likes','dislikes','comment_count','likes_per_view',
       'comments_per_view','total_likes_dislikes_per_view','likes_percentage',
       'dislikes_percentage','publish_hour','title_characters','title_words',
       'description_characters','description_words','total_likes_dislikes']

for column in col:
  x = videos[col].values.astype('float32')
  normed_videos = min_max_scaler.fit_transform(x)
  videos[col] = pd.DataFrame(normed_videos)

# %% [markdown]
# **Remove Duplicates**
#
# The outcome of this experiment will be heavily impacted by duplicate videos

# %%
print(videos.shape[0])
# Out:
# 40209

# %%
videos.drop_duplicates(subset="title", keep="last", inplace=True)

# %%
print(videos.shape[0])
# Out:
# 6328

# %% [markdown]
# **Create functions for tokenizing text**

# %%
nltk.download("stopwords")
STOPWORDS = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
"""
function: tokenize_titles
param(s): text, a string
returns: a list of tokenized strings
"""
def tokenize_titles(text):
  ret_list = []
  # split text into list of words
  data = str(text).split()
  for token in data:
    # remove text that is not made of letters
    word = ""
    for char in token:
      char = char.lower()
      if ascii(char) >= ascii("a") and ascii(char) <= ascii("z"):
        word += char
    # remove empty strings and stopwords
    if word is not "" and word not in STOPWORDS:
      ret_list.append(word)
  return ret_list


"""
function: tokenize_tags
param(s): text, a string
returns: a list of tokenized strings
"""
def tokenize_tags(text):
  ret_list = []
  # split text into list of words
  data = re.split("\"| |\|", str(text))
  for token in data:
    # remove text that is not made of letters
    word = ""
    for char in token:
      char = char.lower()
      if ascii(char) >= ascii("a") and ascii(char) <= ascii("z"):
        word += char
    if word is not "" and word not in STOPWORDS:
      ret_list.append(word)

  return ret_list

# %% [markdown]
# **Create ```data``` variable for neural network learning**

# %%
titles = videos["title"].apply(tokenize_titles)
tags = videos["tags"].apply(tokenize_tags)
channels = videos["channel_title"].apply(tokenize_titles)
descriptions = videos["description"].apply(tokenize_titles)
categories_1 = videos["category"].apply(tokenize_titles)

data = titles + tags + channels + descriptions + categories_1

# %% [markdown]
# ## Learning Word Embeddings with word2vec

# %% [markdown]
# For this sub-experiment, we will test the gensim Word2Vec model on our daily top trending YouTube dataset.

# %% [markdown]
# **word2vec (cbow)**

# %% [markdown]
# The models used for this sub-experiment are word embedding neural networks that learn the values of words so that the words are quantifiable
#
# The first function, ```model``` is a function that is trained using a continuous bag of words

# %%
# train continuous bag of words model
cbow_model = Word2Vec(data, min_count=1, size=200, window=5, workers=4)

# %% [markdown]
# **word2vec (sg)**

# %% [markdown]
# The second function, ```sg_model```, is a function that uses skip grams

# %%
# train skip gram model
sg_model = Word2Vec(data, min_count = 1, size = 200, window = 5, sg = 1, workers=4)

# %% [markdown]
# ***
# **Test examples**

# %%
# source: geeksforgeeks

print("Cosine similarity between 'black' " + "and 'black' - CBOW:     {0:.4f}".format(cbow_model.wv.similarity("black", "black")))
print("Cosine similarity between 'black' " + "and 'black' - SG:       {0:.4f}".format(sg_model.wv.similarity("black", "black")))

print("Cosine similarity between 'panther' " + "and 'panther' - CBOW: {0:.4f}".format(cbow_model.wv.similarity("panther", "panther")))
print("Cosine similarity between 'panther' " + "and 'panther' - SG:   {0:.4f}".format(sg_model.wv.similarity("panther", "panther")))

print("Cosine similarity between 'black' " + "and 'panther' - CBOW:   {0:.4f}".format(cbow_model.wv.similarity("black", "panther")))
print("Cosine similarity between 'black' " + "and 'panther' - SG:     {0:.4f}".format(sg_model.wv.similarity("black", "panther")))

print("Cosine similarity between 'panther' " + "and 'black' - CBOW:   {0:.4f}".format(cbow_model.wv.similarity("panther", "black")))
print("Cosine similarity between 'panther' " + "and 'black' - SG:     {0:.4f}".format(sg_model.wv.similarity("panther", "black")))
# Out:
# Cosine similarity between 'black' and 'black' - CBOW:     1.0000
# Cosine similarity between 'black' and 'black' - SG:       1.0000
# Cosine similarity between 'panther' and 'panther' - CBOW: 1.0000
# Cosine similarity between 'panther' and 'panther' - SG:   1.0000
# Cosine similarity between 'black' and 'panther' - CBOW:   0.9612
# Cosine similarity between 'black' and 'panther' - SG:     0.8361
# Cosine similarity between 'panther' and 'black' - CBOW:   0.9612
# Cosine similarity between 'panther' and 'black' - SG:     0.8361
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# **Create functions for comparing two texts**

# %%
"""
function: get_similarities
param(s): text_one, a list of strings; text_two, a list of strings
returns: the average similarity of text_one to text_two
does: gets the similarity (avg) between two lists of strings for cbow and sg 
      word2vec models
"""
def get_similarities(text_one, text_two):
  cbow_total=0
  sg_total=0
  count=0
  for word_one in text_one:
    cbow_max = np.NINF
    sg_max = np.NINF
    for word_two in text_two:
      # get continuous bag of words similarity
      cbow_max = max(cbow_max, cbow_model.wv.similarity(word_one, word_two))
      # get skip gram similarity
      sg_max = max(sg_max, sg_model.wv.similarity(word_one, word_two))
    if cbow_max > np.NINF or sg_max > np.NINF:
      cbow_total += cbow_max
      sg_total += sg_max
      count += 1
  if count is 0:
    return 0, 0
  return cbow_total/count, sg_total/count

# %%
"""
function: word2vecNLP
param(s): list_one, a list of strings; list_two, a list of strings
returns: the average similarity of list_one to list_two
"""
def word2vecNLP(list_one, list_two):
  cbow_list = []
  sg_list = []

  for i in range(len(list_one)):
    cbow, sg = get_similarities(list_one[i], list_two[i])
    cbow_list.append(cbow)
    sg_list.append(sg)

  return cbow_list, sg_list

# %% [markdown]
# Prepare data

# %%
# convert dataframes to lists
titles_list = titles.tolist()
tags_list = tags.tolist()
descriptions_list = descriptions.tolist()
channels_list = channels.tolist()
categories_list = categories_1.tolist()

# %% [markdown]
# **Test with compare tiles and titles**

# %%
cbow, sg = word2vecNLP(titles_list, titles_list)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
print(len(videos))
print(len(cbow))
print(len(sg))
# Out:
# 6328
# 6328
# 6328

# %%
# add lists to dataframe
videos["cbow_titles_titles"] = cbow
videos["sg_titles_titles"] = sg

# %%
# replace 0 values with mean
# we use the mean because the mean also is equal to the word embeddings of the most common words for this document
videos["cbow_titles_titles"] = videos["cbow_titles_titles"].replace(0, videos["cbow_titles_titles"].mean())
videos["sg_titles_titles"]= videos["sg_titles_titles"].replace(0, videos["sg_titles_titles"].mean())

# %%
print("Cosine similarity between titles and titles - CBOW:     {0:.4f}".format(videos["cbow_titles_titles"].mean()))
print("Cosine similarity between titles and titles - SG:       {0:.4f}".format(videos["sg_titles_titles"].mean()))
# Out:
# Cosine similarity between titles and titles - CBOW:     1.0000
# Cosine similarity between titles and titles - SG:       1.0000

# %% [markdown]
# ## Compare Titles and Tags

# %% [markdown]
# **Using word2vec neural networks, get the similarities of titles and tags**

# %%
cbow, sg = word2vecNLP(titles_list, tags_list)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
# add lists to dataframe
videos["cbow_titles_tags"] = cbow
videos["sg_titles_tags"] = sg

# %%
# replace 0 values with mean
videos["cbow_titles_tags"] = videos["cbow_titles_tags"].replace(0.0, videos["cbow_titles_tags"].mean())
videos["sg_titles_tags"] = videos["sg_titles_tags"].replace(0.0, videos["sg_titles_tags"].mean())

# %% [markdown]
# **Average Similarities**

# %%
print("Cosine similarity between titles and tags - CBOW:     {0:.4f}".format(videos["cbow_titles_tags"].mean()))
print("Cosine similarity between titles and tags - SG:       {0:.4f}".format(videos["sg_titles_tags"].mean()))
# Out:
# Cosine similarity between titles and tags - CBOW:     0.9505
# Cosine similarity between titles and tags - SG:       0.8955

# %% [markdown]
# **Visualization**

# %%
videos.plot(kind="scatter", x="views", y="cbow_titles_tags", alpha=0.5)
videos.plot(kind="scatter", x="views", y="sg_titles_tags", alpha=0.5)

# %%
# source https://www.kaggle.com/kabure/extensive-usa-youtube-eda

plt.figure(figsize = (12,18))

plt.subplot(311)
cat_graph_1 = sns.boxplot(x='category',y='cbow_titles_tags',  data=videos)
cat_graph_1.set_xticklabels(cat_graph_1.get_xticklabels(),rotation=45)

plt.subplot(312)
cat_graph_2 = sns.boxplot(x='category',y='sg_titles_tags',  data=videos)
cat_graph_2.set_xticklabels(cat_graph_2.get_xticklabels(),rotation=45)

plt.subplots_adjust(wspace=0.2, hspace=0.5, top=0.9)

plt.show()

# %%
videos.plot(kind="scatter", x="views", y="cbow_titles_tags", alpha=0.1)
videos.plot(kind="scatter", x="views", y="sg_titles_tags", alpha=0.1)

# %% [markdown]
# ## Compare Titles and Descriptions

# %% [markdown]
# **Using Word2Vec neural networks, get the similarities of titles and descriptions**

# %%
cbow, sg = word2vecNLP(titles_list, descriptions_list)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
# add lists to dataframe
videos["cbow_titles_descriptions"] = cbow
videos["sg_titles_descriptions"] = sg

# %%
# replace 0 values with mean
videos["cbow_titles_descriptions"] = videos["cbow_titles_descriptions"].replace(0, videos["cbow_titles_descriptions"].mean())
videos["sg_titles_descriptions"] = videos["sg_titles_descriptions"].replace(0, videos["sg_titles_descriptions"].mean())

# %% [markdown]
# **Average Similarities**

# %%
print("Cosine similarity between titles and descriptions - CBOW:     {0:.4f}".format(videos["cbow_titles_descriptions"].mean()))
print("Cosine similarity between titles and descriptions - SG:       {0:.4f}".format(videos["sg_titles_descriptions"].mean()))
# Out:
# Cosine similarity between titles and descriptions - CBOW:     0.9536
# Cosine similarity between titles and descriptions - SG:       0.9000

# %% [markdown]
# **Visualization**

# %%
videos.plot(kind="scatter", x="views", y="cbow_titles_descriptions", alpha=0.5)
videos.plot(kind="scatter", x="views", y="sg_titles_descriptions", alpha=0.5)

# %%
# source https://www.kaggle.com/kabure/extensive-usa-youtube-eda

plt.figure(figsize = (12,18))

plt.subplot(311)
cat_graph_1 = sns.boxplot(x='category',y='cbow_titles_tags',  data=videos)
cat_graph_1.set_xticklabels(cat_graph_1.get_xticklabels(),rotation=45)

plt.subplot(312)
cat_graph_2 = sns.boxplot(x='category',y='sg_titles_tags',  data=videos)
cat_graph_2.set_xticklabels(cat_graph_2.get_xticklabels(),rotation=45)

plt.subplots_adjust(wspace=0.2, hspace=0.5, top=0.9)

plt.show()

# %% [markdown]
# ## Compare Titles and Channels

# %% [markdown]
# **Using word2vec neural networks, get the similarities of titles and channels**

# %%
cbow, sg = word2vecNLP(titles_list, channels_list)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
# add lists to dataframe
videos["cbow_titles_channels"] = cbow
videos["sg_titles_channels"] = sg

# %%
# replace 0 values with mean
videos["cbow_titles_channels"] = videos["cbow_titles_channels"].replace(0, videos["cbow_titles_channels"].mean())
videos["sg_titles_channels"] = videos["sg_titles_channels"].replace(0, videos["sg_titles_channels"].mean())

# %% [markdown]
# **Average Similarities**

# %%
print("Cosine similarity between titles and channels - CBOW:     {0:.4f}".format(videos["cbow_titles_channels"].mean()))
print("Cosine similarity between titles and channels - SG:       {0:.4f}".format(videos["sg_titles_channels"].mean()))
# Out:
# Cosine similarity between titles and channels - CBOW:     0.7721
# Cosine similarity between titles and channels - SG:       0.6694

# %% [markdown]
# **Visualization**

# %%
videos.plot(kind="scatter", x="views", y="cbow_titles_channels", alpha=0.5)
videos.plot(kind="scatter", x="views", y="sg_titles_channels", alpha=0.5)

# %%
# source https://www.kaggle.com/kabure/extensive-usa-youtube-eda

plt.figure(figsize = (12,18))

plt.subplot(311)
cat_graph_1 = sns.boxplot(x='category',y='cbow_titles_channels',  data=videos)
cat_graph_1.set_xticklabels(cat_graph_1.get_xticklabels(),rotation=45)

plt.subplot(312)
cat_graph_2 = sns.boxplot(x='category',y='sg_titles_channels',  data=videos)
cat_graph_2.set_xticklabels(cat_graph_2.get_xticklabels(),rotation=45)

plt.subplots_adjust(wspace=0.2, hspace=0.5, top=0.9)

plt.show()

# %% [markdown]
# ## Compares Titles and Categories

# %% [markdown]
# **Using word2vec neural networks, get the similarities of titles and categories**

# %%
cbow, sg = word2vecNLP(titles_list, categories_list)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
# add lists to dataframe
videos["cbow_titles_categories"] = cbow
videos["sg_titles_categories"] = sg

# %%
# replace 0 values with mean
videos["cbow_titles_categories"] = videos["cbow_titles_categories"].replace(0, videos["cbow_titles_categories"].mean())
videos["sg_titles_categories"] = videos["sg_titles_categories"].replace(0, videos["sg_titles_categories"].mean())

# %% [markdown]
# **Average Similarities**

# %%
print("Cosine similarity between titles and categories - CBOW:     {0:.4f}".format(videos["cbow_titles_categories"].mean()))
print("Cosine similarity between titles and categories - SG:       {0:.4f}".format(videos["sg_titles_categories"].mean()))
# Out:
# Cosine similarity between titles and categories - CBOW:     0.6126
# Cosine similarity between titles and categories - SG:       0.3740

# %% [markdown]
# **Visualization**

# %%
videos.plot(kind="scatter", x="views", y="cbow_titles_categories", alpha=0.5)
videos.plot(kind="scatter", x="views", y="sg_titles_categories", alpha=0.5)

# %%
# source https://www.kaggle.com/kabure/extensive-usa-youtube-eda

plt.figure(figsize = (12,18))

plt.subplot(311)
cat_graph_1 = sns.boxplot(x='category',y='cbow_titles_categories',  data=videos)
cat_graph_1.set_xticklabels(cat_graph_1.get_xticklabels(),rotation=45)

plt.subplot(312)
cat_graph_2 = sns.boxplot(x='category',y='sg_titles_categories',  data=videos)
cat_graph_2.set_xticklabels(cat_graph_2.get_xticklabels(),rotation=45)

plt.subplots_adjust(wspace=0.2, hspace=0.5, top=0.9)

plt.show()

# %% [markdown]
# ## Compare Tags and Categories

# %% [markdown]
# **Using word2vec neural networks, get the similarities of tags and categories**

# %%
cbow, sg = word2vecNLP(tags_list, categories_list)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
# add lists to dataframe
videos["cbow_tags_categories"] = cbow
videos["sg_tags_categories"] = sg

# %%
# replace 0 values with mean
videos["cbow_tags_categories"] = videos["cbow_tags_categories"].replace(0, videos["cbow_tags_categories"].mean())
videos["sg_tags_categories"] = videos["sg_tags_categories"].replace(0, videos["sg_tags_categories"].mean())

# %% [markdown]
# **Average Similarities**

# %%
print("Cosine similarity between tags and categories - CBOW:     {0:.4f}".format(videos["cbow_tags_categories"].mean()))
print("Cosine similarity between tags and categories - SG:       {0:.4f}".format(videos["sg_tags_categories"].mean()))
# Out:
# Cosine similarity between tags and categories - CBOW:     0.6316
# Cosine similarity between tags and categories - SG:       0.3937

# %% [markdown]
# **Visualization**

# %%
videos.plot(kind="scatter", x="views", y="cbow_tags_categories", alpha=0.5)
videos.plot(kind="scatter", x="views", y="sg_tags_categories", alpha=0.5)

# %%
# source https://www.kaggle.com/kabure/extensive-usa-youtube-eda

plt.figure(figsize = (12,18))

plt.subplot(311)
cat_graph_1 = sns.boxplot(x='category',y='cbow_tags_categories',  data=videos)
cat_graph_1.set_xticklabels(cat_graph_1.get_xticklabels(),rotation=45)

plt.subplot(312)
cat_graph_2 = sns.boxplot(x='category',y='sg_tags_categories',  data=videos)
cat_graph_2.set_xticklabels(cat_graph_2.get_xticklabels(),rotation=45)

plt.subplots_adjust(wspace=0.2, hspace=0.5, top=0.9)

plt.show()

# %% [markdown]
# ## Regression Using word2vec Values

# %%
videos.head(1)
# Out:
#        video_id trending_date  ... cbow_tags_categories sg_tags_categories
# 10  9wRQljFNDW8    2017-11-14  ...             0.735587           0.513585
#
# [1 rows x 42 columns]

# %%
# create training and testing sets
train_dataset = videos.sample(frac=0.8,random_state=12345)
test_dataset = videos.drop(train_dataset.index)

# %%
train_dataset['comments_disabled'] = (train_dataset['comments_disabled'] == 'True').astype(int)
train_dataset['ratings_disabled'] = (train_dataset['ratings_disabled'] == 'True').astype(int)
train_dataset['video_error_or_removed'] = (train_dataset['video_error_or_removed'] == 'True').astype(int)

test_dataset['comments_disabled'] = (test_dataset['comments_disabled'] == 'True').astype(int)
test_dataset['ratings_disabled'] = (test_dataset['ratings_disabled'] == 'True').astype(int)
test_dataset['video_error_or_removed'] = (test_dataset['video_error_or_removed'] == 'True').astype(int)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
train_dataset = train_dataset.drop(columns=['video_id','trending_date',
                                            'channel_title','category',
                                            'category_id','publish_time',
                                            'tags','thumbnail_link',
                                            'description','title',
                                            'publish_date'])

test_dataset = test_dataset.drop(columns=['video_id','trending_date',
                                            'channel_title','category',
                                            'category_id','publish_time',
                                            'tags','thumbnail_link',
                                            'description','title',
                                            'publish_date'])

# %%
train_dataset_ii = train_dataset
test_dataset_ii = test_dataset

# %%
train_dataset.head()
# Out:
#           views     likes  ...  cbow_tags_categories  sg_tags_categories
# 20168  0.004730  0.005062  ...              0.687373            0.628958
# 25278  0.009125  0.021443  ...              0.591578            0.354920
# 4581   0.005432  0.023185  ...              0.587292            0.261684
# 40756       NaN       NaN  ...              0.700421            0.406247
# 23951  0.003771  0.008717  ...              0.630328            0.357706
#
# [5 rows x 31 columns]

# %%
# clean data
train_dataset = train_dataset.dropna()
test_dataset = test_dataset.dropna()

# %%
# get labels
train_labels = train_dataset.pop('views')
test_labels = test_dataset.pop('views')

# %%
# normalize datasets
min_max_scaler = preprocessing.MinMaxScaler()

x = train_dataset.values.astype('float32')
normed_videos = min_max_scaler.fit_transform(x)
train_dataset = pd.DataFrame(normed_videos)

x = test_dataset.values.astype('float32')
normed_videos = min_max_scaler.fit_transform(x)
test_dataset = pd.DataFrame(normed_videos)

# %%
# get lengths of train and test datasets
print(train_dataset.shape[0])
print(test_dataset.shape[0])
# Out:
# 4252
# 1050

# %%
train_dataset=train_dataset.values.astype('float32')
test_dataset=test_dataset.values.astype('float32')

train_labels = train_labels.values.astype('float32')
test_labels = test_labels.values.astype('float32')

# %% [markdown]
# **TensorFlow Model**

# %%
"""
function: build_model
params: neurons, an integer
returns: a keras neural network
does: creates a generic neural network to be replicated for each experiment
"""
def build_model(neurons):
  model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(neurons, activation='relu'),
    tf.keras.layers.Dense(neurons, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1)
  ])
  optimizer = tf.keras.optimizers.RMSprop(0.001)
  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
# build a neural network
model = build_model(150)

# fit the neural network with the training data
train_history = model.fit(train_dataset, train_labels, epochs=100, 
                          validation_split = 0.2,
                          callbacks=[tfdocs.modeling.EpochDots()])

plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 3401 samples, validate on 851 samples
# Epoch 1/100
# 3008/3401 [=========================>....] - ETA: 0s - loss: 0.0109 - mean_absolute_error: 0.0673 - mean_squared_error: 0.0109
# Epoch: 0, loss:0.0097,  mean_absolute_error:0.0615,  mean_squared_error:0.0097,  val_loss:0.0014,  val_mean_absolute_error:0.0292,  val_mean_squared_error:0.0014,
# 3401/3401 [==============================] - 2s 591us/sample - loss: 0.0097 - mean_absolute_error: 0.0615 - mean_squared_error: 0.0097 - val_loss: 0.0014 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0014
# Epoch 2/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 6.2827e-04 - mean_absolute_error: 0.0143 - mean_squared_error: 6.2827e-04 - val_loss: 3.4522e-04 - val_mean_absolute_error: 0.0082 - val_mean_squared_error: 3.4522e-04
# Epoch 3/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 3.7228e-04 - mean_absolute_error: 0.0099 - mean_squared_error: 3.7228e-04 - val_loss: 2.8945e-04 - val_mean_absolute_error: 0.0093 - val_mean_squared_error: 2.8945e-04
# Epoch 4/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 2.6174e-04 - mean_absolute_error: 0.0084 - mean_squared_error: 2.6174e-04 - val_loss: 2.3674e-04 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 2.3674e-04
# Epoch 5/100
# 3401/3401 [==============================] - 0s 92us/sample - loss: 2.5508e-04 - mean_absolute_error: 0.0082 - mean_squared_error: 2.5508e-04 - val_loss: 1.9046e-04 - val_mean_absolute_error: 0.0063 - val_mean_squared_error: 1.9046e-04
# Epoch 6/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 2.4481e-04 - mean_absolute_error: 0.0077 - mean_squared_error: 2.4481e-04 - val_loss: 2.0708e-04 - val_mean_absolute_error: 0.0065 - val_mean_squared_error: 2.0708e-04
# Epoch 7/100
# 3401/3401 [==============================] - 0s 92us/sample - loss: 1.9111e-04 - mean_absolute_error: 0.0069 - mean_squared_error: 1.9111e-04 - val_loss: 2.3063e-04 - val_mean_absolute_error: 0.0074 - val_mean_squared_error: 2.3063e-04
# Epoch 8/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 1.9065e-04 - mean_absolute_error: 0.0067 - mean_squared_error: 1.9065e-04 - val_loss: 1.3389e-04 - val_mean_absolute_error: 0.0062 - val_mean_squared_error: 1.3389e-04
# Epoch 9/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 1.5734e-04 - mean_absolute_error: 0.0064 - mean_squared_error: 1.5734e-04 - val_loss: 1.5994e-04 - val_mean_absolute_error: 0.0061 - val_mean_squared_error: 1.5994e-04
# Epoch 10/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 1.5447e-04 - mean_absolute_error: 0.0063 - mean_squared_error: 1.5447e-04 - val_loss: 1.1695e-04 - val_mean_absolute_error: 0.0065 - val_mean_squared_error: 1.1695e-04
# Epoch 11/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 1.3340e-04 - mean_absolute_error: 0.0062 - mean_squared_error: 1.3340e-04 - val_loss: 6.5621e-04 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 6.5621e-04
# Epoch 12/100
# 3401/3401 [==============================] - 0s 93us/sample - loss: 1.4551e-04 - mean_absolute_error: 0.0060 - mean_squared_error: 1.4551e-04 - val_loss: 9.1073e-05 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 9.1073e-05
# Epoch 13/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 1.3426e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.3426e-04 - val_loss: 4.2832e-04 - val_mean_absolute_error: 0.0179 - val_mean_squared_error: 4.2832e-04
# Epoch 14/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 1.0488e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.0488e-04 - val_loss: 7.0959e-05 - val_mean_absolute_error: 0.0041 - val_mean_squared_error: 7.0959e-05
# Epoch 15/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 1.2324e-04 - mean_absolute_error: 0.0054 - mean_squared_error: 1.2324e-04 - val_loss: 9.3424e-05 - val_mean_absolute_error: 0.0052 - val_mean_squared_error: 9.3424e-05
# Epoch 16/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 1.0180e-04 - mean_absolute_error: 0.0053 - mean_squared_error: 1.0180e-04 - val_loss: 1.1000e-04 - val_mean_absolute_error: 0.0049 - val_mean_squared_error: 1.1000e-04
# Epoch 17/100
# 3401/3401 [==============================] - 0s 94us/sample - loss: 9.6147e-05 - mean_absolute_error: 0.0051 - mean_squared_error: 9.6146e-05 - val_loss: 8.3715e-05 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 8.3715e-05
# Epoch 18/100
# 3401/3401 [==============================] - 0s 93us/sample - loss: 1.0058e-04 - mean_absolute_error: 0.0052 - mean_squared_error: 1.0058e-04 - val_loss: 1.1884e-04 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 1.1884e-04
# Epoch 19/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 1.3010e-04 - mean_absolute_error: 0.0050 - mean_squared_error: 1.3010e-04 - val_loss: 9.6474e-05 - val_mean_absolute_error: 0.0062 - val_mean_squared_error: 9.6474e-05
# Epoch 20/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 9.5983e-05 - mean_absolute_error: 0.0049 - mean_squared_error: 9.5983e-05 - val_loss: 4.8347e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 4.8347e-05
# Epoch 21/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 1.1994e-04 - mean_absolute_error: 0.0048 - mean_squared_error: 1.1994e-04 - val_loss: 7.2781e-05 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 7.2781e-05
# Epoch 22/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 7.3919e-05 - mean_absolute_error: 0.0047 - mean_squared_error: 7.3919e-05 - val_loss: 5.3661e-05 - val_mean_absolute_error: 0.0038 - val_mean_squared_error: 5.3661e-05
# Epoch 23/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 8.6291e-05 - mean_absolute_error: 0.0048 - mean_squared_error: 8.6291e-05 - val_loss: 7.7231e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 7.7231e-05
# Epoch 24/100
# 3401/3401 [==============================] - 0s 94us/sample - loss: 7.4197e-05 - mean_absolute_error: 0.0046 - mean_squared_error: 7.4197e-05 - val_loss: 8.3809e-05 - val_mean_absolute_error: 0.0052 - val_mean_squared_error: 8.3809e-05
# Epoch 25/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 7.1835e-05 - mean_absolute_error: 0.0044 - mean_squared_error: 7.1835e-05 - val_loss: 7.8198e-05 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 7.8198e-05
# Epoch 26/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 6.0933e-05 - mean_absolute_error: 0.0043 - mean_squared_error: 6.0933e-05 - val_loss: 5.0984e-05 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 5.0984e-05
# Epoch 27/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 6.6551e-05 - mean_absolute_error: 0.0043 - mean_squared_error: 6.6551e-05 - val_loss: 1.1244e-04 - val_mean_absolute_error: 0.0052 - val_mean_squared_error: 1.1244e-04
# Epoch 28/100
# 3401/3401 [==============================] - 0s 111us/sample - loss: 6.3478e-05 - mean_absolute_error: 0.0041 - mean_squared_error: 6.3478e-05 - val_loss: 3.8682e-05 - val_mean_absolute_error: 0.0028 - val_mean_squared_error: 3.8682e-05
# Epoch 29/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 6.9171e-05 - mean_absolute_error: 0.0042 - mean_squared_error: 6.9171e-05 - val_loss: 4.8861e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 4.8861e-05
# Epoch 30/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 8.2576e-05 - mean_absolute_error: 0.0042 - mean_squared_error: 8.2576e-05 - val_loss: 1.6204e-04 - val_mean_absolute_error: 0.0083 - val_mean_squared_error: 1.6204e-04
# Epoch 31/100
# 3401/3401 [==============================] - 0s 94us/sample - loss: 5.5448e-05 - mean_absolute_error: 0.0039 - mean_squared_error: 5.5448e-05 - val_loss: 5.7367e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 5.7367e-05
# Epoch 32/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 7.0650e-05 - mean_absolute_error: 0.0039 - mean_squared_error: 7.0650e-05 - val_loss: 6.4184e-05 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 6.4184e-05
# Epoch 33/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 6.3417e-05 - mean_absolute_error: 0.0038 - mean_squared_error: 6.3417e-05 - val_loss: 4.0901e-05 - val_mean_absolute_error: 0.0027 - val_mean_squared_error: 4.0901e-05
# Epoch 34/100
# 3401/3401 [==============================] - 0s 104us/sample - loss: 5.4357e-05 - mean_absolute_error: 0.0038 - mean_squared_error: 5.4357e-05 - val_loss: 1.0930e-04 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 1.0930e-04
# Epoch 35/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 7.3098e-05 - mean_absolute_error: 0.0038 - mean_squared_error: 7.3098e-05 - val_loss: 1.2747e-04 - val_mean_absolute_error: 0.0081 - val_mean_squared_error: 1.2747e-04
# Epoch 36/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 6.7890e-05 - mean_absolute_error: 0.0039 - mean_squared_error: 6.7890e-05 - val_loss: 2.7254e-05 - val_mean_absolute_error: 0.0025 - val_mean_squared_error: 2.7254e-05
# Epoch 37/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 7.2403e-05 - mean_absolute_error: 0.0037 - mean_squared_error: 7.2403e-05 - val_loss: 6.7942e-05 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 6.7942e-05
# Epoch 38/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 6.2465e-05 - mean_absolute_error: 0.0039 - mean_squared_error: 6.2465e-05 - val_loss: 3.5862e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 3.5862e-05
# Epoch 39/100
# 3401/3401 [==============================] - 0s 104us/sample - loss: 5.3221e-05 - mean_absolute_error: 0.0037 - mean_squared_error: 5.3221e-05 - val_loss: 2.7570e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 2.7570e-05
# Epoch 40/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 4.8046e-05 - mean_absolute_error: 0.0036 - mean_squared_error: 4.8046e-05 - val_loss: 1.2543e-04 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 1.2543e-04
# Epoch 41/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 6.1052e-05 - mean_absolute_error: 0.0037 - mean_squared_error: 6.1052e-05 - val_loss: 3.7059e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 3.7059e-05
# Epoch 42/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 4.6426e-05 - mean_absolute_error: 0.0034 - mean_squared_error: 4.6426e-05 - val_loss: 3.3704e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 3.3704e-05
# Epoch 43/100
# 3401/3401 [==============================] - 0s 103us/sample - loss: 5.2572e-05 - mean_absolute_error: 0.0037 - mean_squared_error: 5.2572e-05 - val_loss: 3.8803e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 3.8803e-05
# Epoch 44/100
# 3401/3401 [==============================] - 0s 106us/sample - loss: 5.0233e-05 - mean_absolute_error: 0.0035 - mean_squared_error: 5.0233e-05 - val_loss: 3.7684e-05 - val_mean_absolute_error: 0.0034 - val_mean_squared_error: 3.7684e-05
# Epoch 45/100
# 3401/3401 [==============================] - 0s 107us/sample - loss: 4.1153e-05 - mean_absolute_error: 0.0033 - mean_squared_error: 4.1153e-05 - val_loss: 2.7620e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 2.7620e-05
# Epoch 46/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 5.9641e-05 - mean_absolute_error: 0.0036 - mean_squared_error: 5.9641e-05 - val_loss: 6.9092e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 6.9092e-05
# Epoch 47/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 4.8177e-05 - mean_absolute_error: 0.0034 - mean_squared_error: 4.8177e-05 - val_loss: 5.6709e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 5.6709e-05
# Epoch 48/100
# 3401/3401 [==============================] - 0s 104us/sample - loss: 6.8454e-05 - mean_absolute_error: 0.0037 - mean_squared_error: 6.8454e-05 - val_loss: 8.8573e-05 - val_mean_absolute_error: 0.0062 - val_mean_squared_error: 8.8573e-05
# Epoch 49/100
# 3401/3401 [==============================] - 0s 112us/sample - loss: 5.5229e-05 - mean_absolute_error: 0.0034 - mean_squared_error: 5.5229e-05 - val_loss: 4.0825e-05 - val_mean_absolute_error: 0.0025 - val_mean_squared_error: 4.0825e-05
# Epoch 50/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 5.3579e-05 - mean_absolute_error: 0.0035 - mean_squared_error: 5.3579e-05 - val_loss: 2.5834e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 2.5834e-05
# Epoch 51/100
# 3401/3401 [==============================] - 0s 105us/sample - loss: 3.9469e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 3.9469e-05 - val_loss: 3.0625e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 3.0625e-05
# Epoch 52/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 5.8550e-05 - mean_absolute_error: 0.0035 - mean_squared_error: 5.8550e-05 - val_loss: 2.8169e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 2.8169e-05
# Epoch 53/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 5.5901e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 5.5901e-05 - val_loss: 3.1894e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 3.1894e-05
# Epoch 54/100
# 3401/3401 [==============================] - 0s 106us/sample - loss: 6.1262e-05 - mean_absolute_error: 0.0034 - mean_squared_error: 6.1262e-05 - val_loss: 2.4946e-05 - val_mean_absolute_error: 0.0027 - val_mean_squared_error: 2.4946e-05
# Epoch 55/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 5.6433e-05 - mean_absolute_error: 0.0034 - mean_squared_error: 5.6433e-05 - val_loss: 3.5911e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 3.5911e-05
# Epoch 56/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 5.5649e-05 - mean_absolute_error: 0.0034 - mean_squared_error: 5.5649e-05 - val_loss: 2.1367e-05 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 2.1367e-05
# Epoch 57/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 4.0109e-05 - mean_absolute_error: 0.0031 - mean_squared_error: 4.0109e-05 - val_loss: 3.7989e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 3.7989e-05
# Epoch 58/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 4.2709e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 4.2709e-05 - val_loss: 1.3285e-04 - val_mean_absolute_error: 0.0050 - val_mean_squared_error: 1.3285e-04
# Epoch 59/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 4.5412e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 4.5412e-05 - val_loss: 2.3792e-05 - val_mean_absolute_error: 0.0021 - val_mean_squared_error: 2.3792e-05
# Epoch 60/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 5.1569e-05 - mean_absolute_error: 0.0033 - mean_squared_error: 5.1569e-05 - val_loss: 2.8376e-05 - val_mean_absolute_error: 0.0029 - val_mean_squared_error: 2.8376e-05
# Epoch 61/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 4.1971e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 4.1971e-05 - val_loss: 5.1869e-05 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 5.1869e-05
# Epoch 62/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 5.2879e-05 - mean_absolute_error: 0.0033 - mean_squared_error: 5.2879e-05 - val_loss: 2.2342e-05 - val_mean_absolute_error: 0.0022 - val_mean_squared_error: 2.2342e-05
# Epoch 63/100
# 3401/3401 [==============================] - 0s 106us/sample - loss: 3.7920e-05 - mean_absolute_error: 0.0031 - mean_squared_error: 3.7920e-05 - val_loss: 2.2550e-05 - val_mean_absolute_error: 0.0021 - val_mean_squared_error: 2.2550e-05
# Epoch 64/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 5.3660e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 5.3660e-05 - val_loss: 5.2362e-05 - val_mean_absolute_error: 0.0053 - val_mean_squared_error: 5.2362e-05
# Epoch 65/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 4.4038e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 4.4038e-05 - val_loss: 4.3282e-05 - val_mean_absolute_error: 0.0023 - val_mean_squared_error: 4.3282e-05
# Epoch 66/100
# 3401/3401 [==============================] - 0s 108us/sample - loss: 4.4174e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 4.4174e-05 - val_loss: 2.1080e-05 - val_mean_absolute_error: 0.0022 - val_mean_squared_error: 2.1080e-05
# Epoch 67/100
# 3401/3401 [==============================] - 0s 107us/sample - loss: 5.3763e-05 - mean_absolute_error: 0.0033 - mean_squared_error: 5.3763e-05 - val_loss: 3.4683e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 3.4683e-05
# Epoch 68/100
# 3401/3401 [==============================] - 0s 107us/sample - loss: 4.6816e-05 - mean_absolute_error: 0.0031 - mean_squared_error: 4.6816e-05 - val_loss: 2.5058e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 2.5058e-05
# Epoch 69/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 4.6292e-05 - mean_absolute_error: 0.0031 - mean_squared_error: 4.6292e-05 - val_loss: 2.5380e-04 - val_mean_absolute_error: 0.0092 - val_mean_squared_error: 2.5380e-04
# Epoch 70/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 4.5363e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 4.5363e-05 - val_loss: 1.7596e-05 - val_mean_absolute_error: 0.0022 - val_mean_squared_error: 1.7596e-05
# Epoch 71/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 4.2140e-05 - mean_absolute_error: 0.0031 - mean_squared_error: 4.2140e-05 - val_loss: 2.6230e-05 - val_mean_absolute_error: 0.0025 - val_mean_squared_error: 2.6230e-05
# Epoch 72/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 4.5237e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 4.5237e-05 - val_loss: 4.2722e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 4.2722e-05
# Epoch 73/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 4.6281e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 4.6281e-05 - val_loss: 8.7548e-05 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 8.7548e-05
# Epoch 74/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 5.1442e-05 - mean_absolute_error: 0.0030 - mean_squared_error: 5.1442e-05 - val_loss: 2.2431e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 2.2431e-05
# Epoch 75/100
# 3401/3401 [==============================] - 0s 107us/sample - loss: 4.1936e-05 - mean_absolute_error: 0.0029 - mean_squared_error: 4.1936e-05 - val_loss: 1.7129e-05 - val_mean_absolute_error: 0.0018 - val_mean_squared_error: 1.7129e-05
# Epoch 76/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 4.5183e-05 - mean_absolute_error: 0.0031 - mean_squared_error: 4.5183e-05 - val_loss: 2.3821e-05 - val_mean_absolute_error: 0.0038 - val_mean_squared_error: 2.3821e-05
# Epoch 77/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 3.8394e-05 - mean_absolute_error: 0.0029 - mean_squared_error: 3.8394e-05 - val_loss: 3.0906e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 3.0906e-05
# Epoch 78/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 3.6597e-05 - mean_absolute_error: 0.0030 - mean_squared_error: 3.6597e-05 - val_loss: 2.5491e-05 - val_mean_absolute_error: 0.0020 - val_mean_squared_error: 2.5491e-05
# Epoch 79/100
# 3401/3401 [==============================] - 0s 93us/sample - loss: 4.2731e-05 - mean_absolute_error: 0.0031 - mean_squared_error: 4.2731e-05 - val_loss: 3.1446e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 3.1446e-05
# Epoch 80/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 4.0555e-05 - mean_absolute_error: 0.0032 - mean_squared_error: 4.0555e-05 - val_loss: 2.4331e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 2.4331e-05
# Epoch 81/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 3.5545e-05 - mean_absolute_error: 0.0030 - mean_squared_error: 3.5545e-05 - val_loss: 1.8049e-05 - val_mean_absolute_error: 0.0023 - val_mean_squared_error: 1.8049e-05
# Epoch 82/100
# 3401/3401 [==============================] - 0s 93us/sample - loss: 4.5662e-05 - mean_absolute_error: 0.0030 - mean_squared_error: 4.5662e-05 - val_loss: 5.9721e-05 - val_mean_absolute_error: 0.0028 - val_mean_squared_error: 5.9720e-05
# Epoch 83/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 4.3524e-05 - mean_absolute_error: 0.0030 - mean_squared_error: 4.3524e-05 - val_loss: 3.5664e-05 - val_mean_absolute_error: 0.0039 - val_mean_squared_error: 3.5664e-05
# Epoch 84/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 3.0118e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 3.0118e-05 - val_loss: 3.0046e-05 - val_mean_absolute_error: 0.0020 - val_mean_squared_error: 3.0046e-05
# Epoch 85/100
# 3401/3401 [==============================] - 0s 94us/sample - loss: 4.3403e-05 - mean_absolute_error: 0.0029 - mean_squared_error: 4.3403e-05 - val_loss: 1.5811e-05 - val_mean_absolute_error: 0.0016 - val_mean_squared_error: 1.5811e-05
# Epoch 86/100
# 3401/3401 [==============================] - 0s 94us/sample - loss: 3.3240e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 3.3240e-05 - val_loss: 3.1291e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 3.1291e-05
# Epoch 87/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 4.2183e-05 - mean_absolute_error: 0.0029 - mean_squared_error: 4.2183e-05 - val_loss: 1.8039e-05 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 1.8039e-05
# Epoch 88/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 4.0765e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 4.0765e-05 - val_loss: 3.5067e-05 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 3.5067e-05
# Epoch 89/100
# 3401/3401 [==============================] - 0s 92us/sample - loss: 3.3432e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 3.3432e-05 - val_loss: 3.5891e-05 - val_mean_absolute_error: 0.0029 - val_mean_squared_error: 3.5891e-05
# Epoch 90/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 4.3849e-05 - mean_absolute_error: 0.0029 - mean_squared_error: 4.3849e-05 - val_loss: 1.6804e-05 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 1.6804e-05
# Epoch 91/100
# 3401/3401 [==============================] - 0s 92us/sample - loss: 3.5871e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 3.5871e-05 - val_loss: 2.2421e-05 - val_mean_absolute_error: 0.0018 - val_mean_squared_error: 2.2421e-05
# Epoch 92/100
# 3401/3401 [==============================] - 0s 93us/sample - loss: 3.8218e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 3.8218e-05 - val_loss: 2.8413e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 2.8413e-05
# Epoch 93/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 3.0778e-05 - mean_absolute_error: 0.0027 - mean_squared_error: 3.0778e-05 - val_loss: 2.2770e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 2.2770e-05
# Epoch 94/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 4.8922e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 4.8922e-05 - val_loss: 8.9847e-05 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 8.9847e-05
# Epoch 95/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 4.0196e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 4.0196e-05 - val_loss: 1.6551e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.6551e-05
# Epoch 96/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 3.0411e-05 - mean_absolute_error: 0.0027 - mean_squared_error: 3.0411e-05 - val_loss: 1.6444e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.6444e-05
# Epoch 97/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 4.9005e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 4.9005e-05 - val_loss: 2.2025e-05 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 2.2025e-05
# Epoch 98/100
# 3401/3401 [==============================] - 0s 94us/sample - loss: 3.7389e-05 - mean_absolute_error: 0.0027 - mean_squared_error: 3.7389e-05 - val_loss: 1.7105e-05 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 1.7105e-05
# Epoch 99/100
# 3401/3401 [==============================] - 0s 109us/sample - loss: 2.9859e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 2.9859e-05 - val_loss: 1.5554e-05 - val_mean_absolute_error: 0.0017 - val_mean_squared_error: 1.5554e-05
# Epoch 100/100
# 3401/3401 [==============================] - 0s 104us/sample - loss: 3.3729e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 3.3729e-05 - val_loss: 3.2671e-05 - val_mean_absolute_error: 0.0029 - val_mean_squared_error: 3.2671e-05

# %%
plotter.plot({'Basic': train_history}, metric = 'mean_absolute_error')
# plt.ylim([0, 1])
plt.ylabel('MAE [views]')
# Out:
# Text(0, 0.5, 'MAE [views]')

# %%
# test the neural network with the test data
loss, mae, mse = model.evaluate(test_dataset, test_labels)
test_predictions = model.predict(test_dataset).flatten()
# Out:
# 1050/1050 [==============================] - 0s 73us/sample - loss: 6.0789e-05 - mean_absolute_error: 0.0033 - mean_squared_error: 6.0789e-05

# %%
a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions, alpha=0.3)
plt.xlabel('True Values [views]')
plt.ylabel('Predictions [views]')
lims = [0, 0.01]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims, color='red')

# %%
train_dataset = train_dataset_ii.drop(columns=['cbow_titles_titles',
                                            'sg_titles_titles',
                                            'cbow_titles_tags','sg_titles_tags',
                                            'cbow_titles_descriptions',
                                            'sg_titles_descriptions',
                                            'cbow_titles_channels',
                                            'sg_titles_channels',
                                            'cbow_titles_categories',
                                            'sg_titles_categories',
                                            'cbow_tags_categories',
                                            'sg_tags_categories'])

test_dataset = test_dataset_ii.drop(columns=['cbow_titles_titles',
                                          'sg_titles_titles',
                                          'cbow_titles_tags','sg_titles_tags',
                                          'cbow_titles_descriptions',
                                          'sg_titles_descriptions',
                                          'cbow_titles_channels',
                                          'sg_titles_channels',
                                          'cbow_titles_categories',
                                          'sg_titles_categories',
                                          'cbow_tags_categories',
                                          'sg_tags_categories'])

# %%
# clean data
train_dataset = train_dataset.dropna()
test_dataset = test_dataset.dropna()

# %%
# normalize datasets
min_max_scaler = preprocessing.MinMaxScaler()

x = train_dataset.values.astype('float32')
normed_videos = min_max_scaler.fit_transform(x)
train_dataset = pd.DataFrame(normed_videos)

x = test_dataset.values.astype('float32')
normed_videos = min_max_scaler.fit_transform(x)
test_dataset = pd.DataFrame(normed_videos)

# %%
# get lengths of train and test datasets
print(train_dataset.shape[0])
print(test_dataset.shape[0])
# Out:
# 4252
# 1050

# %%
train_dataset=train_dataset.values.astype('float32')
test_dataset=test_dataset.values.astype('float32')

# %% [markdown]
# **TensorFlow Model**

# %%
# build a neural network
model = build_model(150)

# fit the neural network with the training data
train_history = model.fit(train_dataset, train_labels, epochs=100, 
                          validation_split = 0.2,
                          callbacks=[tfdocs.modeling.EpochDots()])

plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
# Out:
# Train on 3401 samples, validate on 851 samples
# Epoch 1/100
# 2976/3401 [=========================>....] - ETA: 0s - loss: 0.0018 - mean_absolute_error: 0.0289 - mean_squared_error: 0.0018
# Epoch: 0, loss:0.0016,  mean_absolute_error:0.0268,  mean_squared_error:0.0016,  val_loss:0.0003,  val_mean_absolute_error:0.0164,  val_mean_squared_error:0.0003,
# 3401/3401 [==============================] - 0s 137us/sample - loss: 0.0016 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0016 - val_loss: 3.3394e-04 - val_mean_absolute_error: 0.0164 - val_mean_squared_error: 3.3394e-04
# Epoch 2/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 1.8308e-04 - mean_absolute_error: 0.0081 - mean_squared_error: 1.8308e-04 - val_loss: 1.0042e-04 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 1.0042e-04
# Epoch 3/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 6.7227e-05 - mean_absolute_error: 0.0052 - mean_squared_error: 6.7227e-05 - val_loss: 1.2992e-04 - val_mean_absolute_error: 0.0067 - val_mean_squared_error: 1.2992e-04
# Epoch 4/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 7.9431e-05 - mean_absolute_error: 0.0046 - mean_squared_error: 7.9431e-05 - val_loss: 3.9110e-05 - val_mean_absolute_error: 0.0048 - val_mean_squared_error: 3.9110e-05
# Epoch 5/100
# 3401/3401 [==============================] - 0s 103us/sample - loss: 5.4874e-05 - mean_absolute_error: 0.0043 - mean_squared_error: 5.4874e-05 - val_loss: 4.7067e-05 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 4.7067e-05
# Epoch 6/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 4.9568e-05 - mean_absolute_error: 0.0039 - mean_squared_error: 4.9568e-05 - val_loss: 5.3700e-05 - val_mean_absolute_error: 0.0038 - val_mean_squared_error: 5.3700e-05
# Epoch 7/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 5.4303e-05 - mean_absolute_error: 0.0038 - mean_squared_error: 5.4303e-05 - val_loss: 1.1543e-05 - val_mean_absolute_error: 0.0025 - val_mean_squared_error: 1.1543e-05
# Epoch 8/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 4.9845e-05 - mean_absolute_error: 0.0036 - mean_squared_error: 4.9845e-05 - val_loss: 3.5235e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 3.5235e-05
# Epoch 9/100
# 3401/3401 [==============================] - 0s 103us/sample - loss: 2.7926e-05 - mean_absolute_error: 0.0031 - mean_squared_error: 2.7926e-05 - val_loss: 1.8011e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 1.8011e-05
# Epoch 10/100
# 3401/3401 [==============================] - 0s 90us/sample - loss: 3.8485e-05 - mean_absolute_error: 0.0031 - mean_squared_error: 3.8485e-05 - val_loss: 3.7825e-05 - val_mean_absolute_error: 0.0027 - val_mean_squared_error: 3.7825e-05
# Epoch 11/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 3.2795e-05 - mean_absolute_error: 0.0030 - mean_squared_error: 3.2795e-05 - val_loss: 7.5405e-06 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 7.5405e-06
# Epoch 12/100
# 3401/3401 [==============================] - 0s 103us/sample - loss: 2.6765e-05 - mean_absolute_error: 0.0029 - mean_squared_error: 2.6765e-05 - val_loss: 8.9275e-05 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 8.9275e-05
# Epoch 13/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 4.1407e-05 - mean_absolute_error: 0.0029 - mean_squared_error: 4.1407e-05 - val_loss: 2.4335e-05 - val_mean_absolute_error: 0.0045 - val_mean_squared_error: 2.4335e-05
# Epoch 14/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 2.4133e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 2.4133e-05 - val_loss: 6.8412e-06 - val_mean_absolute_error: 0.0016 - val_mean_squared_error: 6.8412e-06
# Epoch 15/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 3.0878e-05 - mean_absolute_error: 0.0028 - mean_squared_error: 3.0878e-05 - val_loss: 7.4317e-06 - val_mean_absolute_error: 0.0015 - val_mean_squared_error: 7.4317e-06
# Epoch 16/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 2.9295e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 2.9295e-05 - val_loss: 1.1426e-05 - val_mean_absolute_error: 0.0020 - val_mean_squared_error: 1.1426e-05
# Epoch 17/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 2.5975e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 2.5975e-05 - val_loss: 8.2093e-06 - val_mean_absolute_error: 0.0023 - val_mean_squared_error: 8.2093e-06
# Epoch 18/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 2.6430e-05 - mean_absolute_error: 0.0026 - mean_squared_error: 2.6430e-05 - val_loss: 4.6007e-06 - val_mean_absolute_error: 0.0014 - val_mean_squared_error: 4.6007e-06
# Epoch 19/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 1.9448e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 1.9448e-05 - val_loss: 1.0234e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.0234e-05
# Epoch 20/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 2.6812e-05 - mean_absolute_error: 0.0025 - mean_squared_error: 2.6812e-05 - val_loss: 1.0290e-05 - val_mean_absolute_error: 0.0021 - val_mean_squared_error: 1.0290e-05
# Epoch 21/100
# 3401/3401 [==============================] - 0s 104us/sample - loss: 2.2558e-05 - mean_absolute_error: 0.0024 - mean_squared_error: 2.2558e-05 - val_loss: 4.9316e-06 - val_mean_absolute_error: 0.0012 - val_mean_squared_error: 4.9316e-06
# Epoch 22/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 2.2343e-05 - mean_absolute_error: 0.0024 - mean_squared_error: 2.2343e-05 - val_loss: 8.3734e-06 - val_mean_absolute_error: 0.0014 - val_mean_squared_error: 8.3734e-06
# Epoch 23/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 2.1371e-05 - mean_absolute_error: 0.0023 - mean_squared_error: 2.1371e-05 - val_loss: 5.2562e-06 - val_mean_absolute_error: 0.0017 - val_mean_squared_error: 5.2562e-06
# Epoch 24/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 3.4024e-05 - mean_absolute_error: 0.0024 - mean_squared_error: 3.4024e-05 - val_loss: 3.6102e-06 - val_mean_absolute_error: 0.0013 - val_mean_squared_error: 3.6102e-06
# Epoch 25/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 3.0357e-05 - mean_absolute_error: 0.0024 - mean_squared_error: 3.0357e-05 - val_loss: 4.3934e-06 - val_mean_absolute_error: 0.0013 - val_mean_squared_error: 4.3934e-06
# Epoch 26/100
# 3401/3401 [==============================] - 0s 110us/sample - loss: 2.2552e-05 - mean_absolute_error: 0.0023 - mean_squared_error: 2.2552e-05 - val_loss: 7.3078e-06 - val_mean_absolute_error: 0.0017 - val_mean_squared_error: 7.3078e-06
# Epoch 27/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 2.0113e-05 - mean_absolute_error: 0.0022 - mean_squared_error: 2.0113e-05 - val_loss: 4.4455e-06 - val_mean_absolute_error: 0.0010 - val_mean_squared_error: 4.4455e-06
# Epoch 28/100
# 3401/3401 [==============================] - 0s 108us/sample - loss: 2.0064e-05 - mean_absolute_error: 0.0023 - mean_squared_error: 2.0064e-05 - val_loss: 1.2539e-05 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 1.2539e-05
# Epoch 29/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 1.8753e-05 - mean_absolute_error: 0.0022 - mean_squared_error: 1.8753e-05 - val_loss: 1.5287e-05 - val_mean_absolute_error: 0.0031 - val_mean_squared_error: 1.5287e-05
# Epoch 30/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 1.9791e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 1.9791e-05 - val_loss: 1.5345e-05 - val_mean_absolute_error: 0.0018 - val_mean_squared_error: 1.5345e-05
# Epoch 31/100
# 3401/3401 [==============================] - 0s 93us/sample - loss: 2.2504e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.2504e-05 - val_loss: 1.9365e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 1.9365e-05
# Epoch 32/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 2.2304e-05 - mean_absolute_error: 0.0022 - mean_squared_error: 2.2304e-05 - val_loss: 1.4196e-05 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 1.4196e-05
# Epoch 33/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 3.0216e-05 - mean_absolute_error: 0.0022 - mean_squared_error: 3.0216e-05 - val_loss: 1.0906e-05 - val_mean_absolute_error: 0.0017 - val_mean_squared_error: 1.0906e-05
# Epoch 34/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 2.0636e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.0636e-05 - val_loss: 1.9797e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 1.9797e-05
# Epoch 35/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 2.0542e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.0542e-05 - val_loss: 7.1289e-06 - val_mean_absolute_error: 0.0020 - val_mean_squared_error: 7.1289e-06
# Epoch 36/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 2.7502e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.7502e-05 - val_loss: 3.6884e-06 - val_mean_absolute_error: 0.0010 - val_mean_squared_error: 3.6884e-06
# Epoch 37/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 2.8358e-05 - mean_absolute_error: 0.0022 - mean_squared_error: 2.8358e-05 - val_loss: 5.3295e-06 - val_mean_absolute_error: 0.0014 - val_mean_squared_error: 5.3295e-06
# Epoch 38/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 1.9657e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 1.9657e-05 - val_loss: 7.8719e-05 - val_mean_absolute_error: 0.0047 - val_mean_squared_error: 7.8719e-05
# Epoch 39/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 1.9501e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 1.9501e-05 - val_loss: 2.7379e-06 - val_mean_absolute_error: 8.9875e-04 - val_mean_squared_error: 2.7379e-06
# Epoch 40/100
# 3401/3401 [==============================] - 0s 104us/sample - loss: 1.5628e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 1.5628e-05 - val_loss: 3.9712e-06 - val_mean_absolute_error: 0.0014 - val_mean_squared_error: 3.9712e-06
# Epoch 41/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 2.1304e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.1304e-05 - val_loss: 1.3845e-05 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 1.3845e-05
# Epoch 42/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 1.4439e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 1.4439e-05 - val_loss: 3.0418e-06 - val_mean_absolute_error: 9.6535e-04 - val_mean_squared_error: 3.0418e-06
# Epoch 43/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 1.8002e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 1.8002e-05 - val_loss: 4.7883e-06 - val_mean_absolute_error: 0.0014 - val_mean_squared_error: 4.7883e-06
# Epoch 44/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 2.1013e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.1013e-05 - val_loss: 4.8395e-06 - val_mean_absolute_error: 0.0012 - val_mean_squared_error: 4.8395e-06
# Epoch 45/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 2.7722e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.7722e-05 - val_loss: 6.2601e-06 - val_mean_absolute_error: 0.0018 - val_mean_squared_error: 6.2601e-06
# Epoch 46/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 1.8948e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 1.8948e-05 - val_loss: 6.3573e-06 - val_mean_absolute_error: 0.0011 - val_mean_squared_error: 6.3573e-06
# Epoch 47/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 2.0570e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.0570e-05 - val_loss: 6.9521e-06 - val_mean_absolute_error: 0.0012 - val_mean_squared_error: 6.9521e-06
# Epoch 48/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 2.2997e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 2.2997e-05 - val_loss: 4.5202e-06 - val_mean_absolute_error: 0.0015 - val_mean_squared_error: 4.5202e-06
# Epoch 49/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 2.3436e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.3436e-05 - val_loss: 6.5529e-06 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 6.5529e-06
# Epoch 50/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 1.8201e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 1.8201e-05 - val_loss: 1.7022e-06 - val_mean_absolute_error: 7.5524e-04 - val_mean_squared_error: 1.7022e-06
# Epoch 51/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 1.5549e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.5549e-05 - val_loss: 3.2575e-05 - val_mean_absolute_error: 0.0037 - val_mean_squared_error: 3.2575e-05
# Epoch 52/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 2.0813e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.0813e-05 - val_loss: 6.6635e-06 - val_mean_absolute_error: 0.0020 - val_mean_squared_error: 6.6635e-06
# Epoch 53/100
# 3401/3401 [==============================] - 0s 103us/sample - loss: 1.9961e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.9961e-05 - val_loss: 8.2351e-06 - val_mean_absolute_error: 0.0026 - val_mean_squared_error: 8.2351e-06
# Epoch 54/100
# 3401/3401 [==============================] - 0s 94us/sample - loss: 2.0236e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.0236e-05 - val_loss: 3.7820e-05 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 3.7820e-05
# Epoch 55/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 2.6632e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 2.6632e-05 - val_loss: 3.0058e-06 - val_mean_absolute_error: 0.0014 - val_mean_squared_error: 3.0058e-06
# Epoch 56/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 2.6701e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.6701e-05 - val_loss: 3.1884e-06 - val_mean_absolute_error: 9.8443e-04 - val_mean_squared_error: 3.1884e-06
# Epoch 57/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 1.8192e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.8192e-05 - val_loss: 3.3722e-06 - val_mean_absolute_error: 0.0011 - val_mean_squared_error: 3.3722e-06
# Epoch 58/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 1.5072e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.5072e-05 - val_loss: 2.8971e-06 - val_mean_absolute_error: 0.0010 - val_mean_squared_error: 2.8971e-06
# Epoch 59/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 1.7740e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 1.7740e-05 - val_loss: 4.5445e-06 - val_mean_absolute_error: 8.5466e-04 - val_mean_squared_error: 4.5445e-06
# Epoch 60/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 2.5522e-05 - mean_absolute_error: 0.0021 - mean_squared_error: 2.5522e-05 - val_loss: 2.8891e-06 - val_mean_absolute_error: 7.4868e-04 - val_mean_squared_error: 2.8891e-06
# Epoch 61/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 2.0703e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.0703e-05 - val_loss: 5.6415e-06 - val_mean_absolute_error: 9.6857e-04 - val_mean_squared_error: 5.6415e-06
# Epoch 62/100
# 3401/3401 [==============================] - 0s 94us/sample - loss: 2.1152e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 2.1152e-05 - val_loss: 4.2278e-06 - val_mean_absolute_error: 9.7068e-04 - val_mean_squared_error: 4.2278e-06
# Epoch 63/100
# 3401/3401 [==============================] - 0s 100us/sample - loss: 2.0347e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.0347e-05 - val_loss: 3.9068e-06 - val_mean_absolute_error: 0.0011 - val_mean_squared_error: 3.9068e-06
# Epoch 64/100
# 3401/3401 [==============================] - 0s 104us/sample - loss: 1.8320e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.8320e-05 - val_loss: 8.6553e-06 - val_mean_absolute_error: 0.0014 - val_mean_squared_error: 8.6553e-06
# Epoch 65/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 1.5028e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.5028e-05 - val_loss: 1.2220e-05 - val_mean_absolute_error: 0.0015 - val_mean_squared_error: 1.2220e-05
# Epoch 66/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 1.8512e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 1.8512e-05 - val_loss: 7.7858e-06 - val_mean_absolute_error: 0.0012 - val_mean_squared_error: 7.7858e-06
# Epoch 67/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 1.3874e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.3874e-05 - val_loss: 2.8633e-06 - val_mean_absolute_error: 0.0013 - val_mean_squared_error: 2.8633e-06
# Epoch 68/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 1.6179e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.6179e-05 - val_loss: 3.3337e-06 - val_mean_absolute_error: 0.0012 - val_mean_squared_error: 3.3337e-06
# Epoch 69/100
# 3401/3401 [==============================] - 0s 94us/sample - loss: 2.0239e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 2.0239e-05 - val_loss: 2.7658e-06 - val_mean_absolute_error: 8.2954e-04 - val_mean_squared_error: 2.7658e-06
# Epoch 70/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 1.7093e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 1.7093e-05 - val_loss: 5.4521e-06 - val_mean_absolute_error: 0.0021 - val_mean_squared_error: 5.4521e-06
# Epoch 71/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 1.8117e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.8117e-05 - val_loss: 1.1335e-05 - val_mean_absolute_error: 0.0030 - val_mean_squared_error: 1.1335e-05
# Epoch 72/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 1.8303e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.8303e-05 - val_loss: 6.6447e-06 - val_mean_absolute_error: 0.0012 - val_mean_squared_error: 6.6447e-06
# Epoch 73/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 2.2471e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 2.2471e-05 - val_loss: 2.0031e-06 - val_mean_absolute_error: 7.8474e-04 - val_mean_squared_error: 2.0031e-06
# Epoch 74/100
# 3401/3401 [==============================] - 0s 97us/sample - loss: 1.7484e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 1.7484e-05 - val_loss: 4.8142e-06 - val_mean_absolute_error: 0.0012 - val_mean_squared_error: 4.8142e-06
# Epoch 75/100
# 3401/3401 [==============================] - 0s 95us/sample - loss: 1.3242e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.3242e-05 - val_loss: 9.1435e-06 - val_mean_absolute_error: 0.0017 - val_mean_squared_error: 9.1435e-06
# Epoch 76/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 1.7445e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.7445e-05 - val_loss: 3.3486e-06 - val_mean_absolute_error: 0.0010 - val_mean_squared_error: 3.3486e-06
# Epoch 77/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 1.7714e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.7714e-05 - val_loss: 1.0224e-05 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 1.0224e-05
# Epoch 78/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 1.1794e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.1794e-05 - val_loss: 7.4813e-06 - val_mean_absolute_error: 0.0012 - val_mean_squared_error: 7.4813e-06
# Epoch 79/100
# 3401/3401 [==============================] - 0s 111us/sample - loss: 2.0262e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.0262e-05 - val_loss: 1.9964e-06 - val_mean_absolute_error: 8.8626e-04 - val_mean_squared_error: 1.9964e-06
# Epoch 80/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 1.4381e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 1.4381e-05 - val_loss: 6.6501e-06 - val_mean_absolute_error: 0.0021 - val_mean_squared_error: 6.6501e-06
# Epoch 81/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 2.0121e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 2.0121e-05 - val_loss: 1.7168e-06 - val_mean_absolute_error: 0.0010 - val_mean_squared_error: 1.7168e-06
# Epoch 82/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 1.5402e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 1.5402e-05 - val_loss: 2.1707e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 2.1707e-05
# Epoch 83/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 2.1201e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.1201e-05 - val_loss: 1.0409e-05 - val_mean_absolute_error: 0.0025 - val_mean_squared_error: 1.0409e-05
# Epoch 84/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 2.2930e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 2.2930e-05 - val_loss: 4.9419e-06 - val_mean_absolute_error: 0.0017 - val_mean_squared_error: 4.9419e-06
# Epoch 85/100
# 3401/3401 [==============================] - 0s 101us/sample - loss: 2.5360e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.5360e-05 - val_loss: 5.7686e-06 - val_mean_absolute_error: 0.0012 - val_mean_squared_error: 5.7686e-06
# Epoch 86/100
# 3401/3401 [==============================] - 0s 96us/sample - loss: 1.4700e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.4700e-05 - val_loss: 5.6901e-06 - val_mean_absolute_error: 9.8243e-04 - val_mean_squared_error: 5.6901e-06
# Epoch 87/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 1.8833e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 1.8833e-05 - val_loss: 4.7393e-06 - val_mean_absolute_error: 0.0018 - val_mean_squared_error: 4.7393e-06
# Epoch 88/100
# 3401/3401 [==============================] - 0s 108us/sample - loss: 1.7165e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 1.7165e-05 - val_loss: 6.0929e-06 - val_mean_absolute_error: 7.9869e-04 - val_mean_squared_error: 6.0929e-06
# Epoch 89/100
# 3401/3401 [==============================] - 0s 103us/sample - loss: 2.1674e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.1674e-05 - val_loss: 3.3903e-06 - val_mean_absolute_error: 8.3246e-04 - val_mean_squared_error: 3.3903e-06
# Epoch 90/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 2.3253e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.3253e-05 - val_loss: 6.8055e-06 - val_mean_absolute_error: 0.0019 - val_mean_squared_error: 6.8055e-06
# Epoch 91/100
# 3401/3401 [==============================] - 0s 108us/sample - loss: 2.5861e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.5861e-05 - val_loss: 5.2441e-06 - val_mean_absolute_error: 0.0014 - val_mean_squared_error: 5.2441e-06
# Epoch 92/100
# 3401/3401 [==============================] - 0s 102us/sample - loss: 1.4809e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 1.4809e-05 - val_loss: 1.9356e-06 - val_mean_absolute_error: 9.8249e-04 - val_mean_squared_error: 1.9356e-06
# Epoch 93/100
# 3401/3401 [==============================] - 0s 104us/sample - loss: 1.6546e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.6546e-05 - val_loss: 1.9127e-05 - val_mean_absolute_error: 0.0020 - val_mean_squared_error: 1.9127e-05
# Epoch 94/100
# 3401/3401 [==============================] - 0s 106us/sample - loss: 1.7104e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 1.7104e-05 - val_loss: 5.0639e-06 - val_mean_absolute_error: 0.0015 - val_mean_squared_error: 5.0639e-06
# Epoch 95/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 1.6170e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 1.6170e-05 - val_loss: 1.4634e-05 - val_mean_absolute_error: 0.0016 - val_mean_squared_error: 1.4634e-05
# Epoch 96/100
# 3401/3401 [==============================] - 0s 99us/sample - loss: 1.2117e-05 - mean_absolute_error: 0.0018 - mean_squared_error: 1.2117e-05 - val_loss: 3.8587e-06 - val_mean_absolute_error: 7.8135e-04 - val_mean_squared_error: 3.8587e-06
# Epoch 97/100
# 3401/3401 [==============================] - 0s 105us/sample - loss: 1.9208e-05 - mean_absolute_error: 0.0020 - mean_squared_error: 1.9208e-05 - val_loss: 1.5080e-05 - val_mean_absolute_error: 0.0021 - val_mean_squared_error: 1.5080e-05
# Epoch 98/100
# 3401/3401 [==============================] - 0s 103us/sample - loss: 2.7582e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.7582e-05 - val_loss: 2.7616e-06 - val_mean_absolute_error: 0.0010 - val_mean_squared_error: 2.7616e-06
# Epoch 99/100
# 3401/3401 [==============================] - 0s 98us/sample - loss: 1.4794e-05 - mean_absolute_error: 0.0017 - mean_squared_error: 1.4794e-05 - val_loss: 7.3591e-06 - val_mean_absolute_error: 0.0024 - val_mean_squared_error: 7.3591e-06
# Epoch 100/100
# 3401/3401 [==============================] - 0s 108us/sample - loss: 2.1244e-05 - mean_absolute_error: 0.0019 - mean_squared_error: 2.1244e-05 - val_loss: 5.1035e-06 - val_mean_absolute_error: 8.9722e-04 - val_mean_squared_error: 5.1035e-06

# %%
plotter.plot({'Basic': train_history}, metric = 'mean_absolute_error')
# plt.ylim([0, 1])
plt.ylabel('MAE [views]')
# Out:
# Text(0, 0.5, 'MAE [views]')

# %%
# test the neural network with the test data
loss, mae, mse = model.evaluate(test_dataset, test_labels)
test_predictions = model.predict(test_dataset).flatten()
# Out:
# 1050/1050 [==============================] - 0s 56us/sample - loss: 1.5832e-05 - mean_absolute_error: 0.0011 - mean_squared_error: 1.5832e-05

# %%
a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions, alpha=0.3)
plt.xlabel('True Values [views]')
plt.ylabel('Predictions [views]')
lims = [0, 0.01]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims, color='red')
